# %%
import numpy as np
import pandas as pd
# making a Dataframe from dictionary
students = {
    "name": ['Maya','Ankita','Preet','Maryam','Sahil','Jaishwal'],
    "age": [23,55,64,32,20,16],
    "MaxEducation": ['Bachelor','PHD','PHD','Masters','Undergrad','Intermediate'],
    "course": ['BSCS','Maths','English','Economics','BBA','ICS'],
    "Institute": ['Muhammad Ali Jinnah University','IBA','IBA','King Saud University','Habib University','Bahria College'],
    "email": ['Maya.edu@gmail.com','Ankita.edu@gmail.com','Preet.edu@gmail.com','Maryam.edu@gmail.com','Sahil.edu@gmail.com','Jaishwal.edu@gmail.com']}
students

studentInfo = pd.DataFrame(students)
studentInfo
# Out:
#        name  age  MaxEducation     course                       Institute  \
# 0      Maya   23      Bachelor       BSCS  Muhammad Ali Jinnah University
# 1    Ankita   55           PHD      Maths                             IBA
# 2     Preet   64           PHD    English                             IBA
# 3    Maryam   32       Masters  Economics            King Saud University
# 4     Sahil   20     Undergrad        BBA                Habib University
# 5  Jaishwal   16  Intermediate        ICS                  Bahria College
#
#                     email
# 0      Maya.edu@gmail.com
# 1    Ankita.edu@gmail.com
# 2     Preet.edu@gmail.com
# 3    Maryam.edu@gmail.com
# 4     Sahil.edu@gmail.com
# 5  Jaishwal.edu@gmail.com

# %%
studentInfo.index = [102134232011,102134232012,102134232013,102134232014,102134232015,102134232016]
studentInfo
# Out:
#                   name  age  MaxEducation     course  \
# 102134232011      Maya   23      Bachelor       BSCS
# 102134232012    Ankita   55           PHD      Maths
# 102134232013     Preet   64           PHD    English
# 102134232014    Maryam   32       Masters  Economics
# 102134232015     Sahil   20     Undergrad        BBA
# 102134232016  Jaishwal   16  Intermediate        ICS
#
#                                    Institute                   email
# 102134232011  Muhammad Ali Jinnah University      Maya.edu@gmail.com
# 102134232012                             IBA    Ankita.edu@gmail.com
# 102134232013                             IBA     Preet.edu@gmail.com
# 102134232014            King Saud University    Maryam.edu@gmail.com
# 102134232015                Habib University     Sahil.edu@gmail.com
# 102134232016                  Bahria College  Jaishwal.edu@gmail.com

# %%
# agar ye method use krengy tw sabko change krna hoga
# column name changing method 1
studentInfo.columns = [
    "Name",
    "Age",
    "MaxEducation",
    "Course",
    "Institute",
    "Email"
]
studentInfo
# Out:
#                   Name  Age  MaxEducation     Course  \
# 102134232011      Maya   23      Bachelor       BSCS
# 102134232012    Ankita   55           PHD      Maths
# 102134232013     Preet   64           PHD    English
# 102134232014    Maryam   32       Masters  Economics
# 102134232015     Sahil   20     Undergrad        BBA
# 102134232016  Jaishwal   16  Intermediate        ICS
#
#                                    Institute                   Email
# 102134232011  Muhammad Ali Jinnah University      Maya.edu@gmail.com
# 102134232012                             IBA    Ankita.edu@gmail.com
# 102134232013                             IBA     Preet.edu@gmail.com
# 102134232014            King Saud University    Maryam.edu@gmail.com
# 102134232015                Habib University     Sahil.edu@gmail.com
# 102134232016                  Bahria College  Jaishwal.edu@gmail.com

# %%
# column name renaming method 2
studentInfo.rename(columns={
    "MaxEducation": "Higher Education",
    "Course": "Degree"}, inplace = True)

# %%
studentInfo
# Out:
#                   Name  Age Higher Education     Degree  \
# 102134232011      Maya   23         Bachelor       BSCS
# 102134232012    Ankita   55              PHD      Maths
# 102134232013     Preet   64              PHD    English
# 102134232014    Maryam   32          Masters  Economics
# 102134232015     Sahil   20        Undergrad        BBA
# 102134232016  Jaishwal   16     Intermediate        ICS
#
#                                    Institute                   Email
# 102134232011  Muhammad Ali Jinnah University      Maya.edu@gmail.com
# 102134232012                             IBA    Ankita.edu@gmail.com
# 102134232013                             IBA     Preet.edu@gmail.com
# 102134232014            King Saud University    Maryam.edu@gmail.com
# 102134232015                Habib University     Sahil.edu@gmail.com
# 102134232016                  Bahria College  Jaishwal.edu@gmail.com

# %%
# adding a column
studentInfo["CGPA"]=[3.4,2.6,3.8,4.0,2.9,3.0]

# %%
studentInfo
# Out:
#                   Name  Age Higher Education     Degree  \
# 102134232011      Maya   23         Bachelor       BSCS
# 102134232012    Ankita   55              PHD      Maths
# 102134232013     Preet   64              PHD    English
# 102134232014    Maryam   32          Masters  Economics
# 102134232015     Sahil   20        Undergrad        BBA
# 102134232016  Jaishwal   16     Intermediate        ICS
#
#                                    Institute                   Email  CGPA
# 102134232011  Muhammad Ali Jinnah University      Maya.edu@gmail.com   3.4
# 102134232012                             IBA    Ankita.edu@gmail.com   2.6
# 102134232013                             IBA     Preet.edu@gmail.com   3.8
# 102134232014            King Saud University    Maryam.edu@gmail.com   4.0
# 102134232015                Habib University     Sahil.edu@gmail.com   2.9
# 102134232016                  Bahria College  Jaishwal.edu@gmail.com   3.0

# %%
# Assigning a value by checking column
studentInfo["Adult"] = studentInfo["Age"]>=18
studentInfo
# Out:
#                   Name  Age Higher Education     Degree  \
# 102134232011      Maya   23         Bachelor       BSCS
# 102134232012    Ankita   55              PHD      Maths
# 102134232013     Preet   64              PHD    English
# 102134232014    Maryam   32          Masters  Economics
# 102134232015     Sahil   20        Undergrad        BBA
# 102134232016  Jaishwal   16     Intermediate        ICS
#
#                                    Institute                   Email  CGPA  \
# 102134232011  Muhammad Ali Jinnah University      Maya.edu@gmail.com   3.4
# 102134232012                             IBA    Ankita.edu@gmail.com   2.6
# 102134232013                             IBA     Preet.edu@gmail.com   3.8
# 102134232014            King Saud University    Maryam.edu@gmail.com   4.0
# 102134232015                Habib University     Sahil.edu@gmail.com   2.9
# 102134232016                  Bahria College  Jaishwal.edu@gmail.com   3.0
#
#               Adult
# 102134232011   True
# 102134232012   True
# 102134232013   True
# 102134232014   True
# 102134232015   True
# 102134232016  False

# %%
# Adding same value to every column
studentInfo["Country"] = "Pakistan"
studentInfo
# Out:
#                   Name  Age Higher Education     Degree  \
# 102134232011      Maya   23         Bachelor       BSCS
# 102134232012    Ankita   55              PHD      Maths
# 102134232013     Preet   64              PHD    English
# 102134232014    Maryam   32          Masters  Economics
# 102134232015     Sahil   20        Undergrad        BBA
# 102134232016  Jaishwal   16     Intermediate        ICS
#
#                                    Institute                   Email  CGPA  \
# 102134232011  Muhammad Ali Jinnah University      Maya.edu@gmail.com   3.4
# 102134232012                             IBA    Ankita.edu@gmail.com   2.6
# 102134232013                             IBA     Preet.edu@gmail.com   3.8
# 102134232014            King Saud University    Maryam.edu@gmail.com   4.0
# 102134232015                Habib University     Sahil.edu@gmail.com   2.9
# 102134232016                  Bahria College  Jaishwal.edu@gmail.com   3.0
#
#               Adult   Country
# 102134232011   True  Pakistan
# 102134232012   True  Pakistan
# 102134232013   True  Pakistan
# 102134232014   True  Pakistan
# 102134232015   True  Pakistan
# 102134232016  False  Pakistan

# %%
studentInfo.index = [1,2,3,4,5,6]
studentInfo
# Out:
#        Name  Age Higher Education     Degree                       Institute  \
# 1      Maya   23         Bachelor       BSCS  Muhammad Ali Jinnah University
# 2    Ankita   55              PHD      Maths                             IBA
# 3     Preet   64              PHD    English                             IBA
# 4    Maryam   32          Masters  Economics            King Saud University
# 5     Sahil   20        Undergrad        BBA                Habib University
# 6  Jaishwal   16     Intermediate        ICS                  Bahria College
#
#                     Email  CGPA  Adult   Country
# 1      Maya.edu@gmail.com   3.4   True  Pakistan
# 2    Ankita.edu@gmail.com   2.6   True  Pakistan
# 3     Preet.edu@gmail.com   3.8   True  Pakistan
# 4    Maryam.edu@gmail.com   4.0   True  Pakistan
# 5     Sahil.edu@gmail.com   2.9   True  Pakistan
# 6  Jaishwal.edu@gmail.com   3.0  False  Pakistan

# %%
# Assigning column at a specific location
studentInfo.insert(2,"Gender",["Female","Female","Female","Female","Male","Male",])
studentInfo
# Out:
#        Name  Age  Gender Higher Education     Degree  \
# 1      Maya   23  Female         Bachelor       BSCS
# 2    Ankita   55  Female              PHD      Maths
# 3     Preet   64  Female              PHD    English
# 4    Maryam   32  Female          Masters  Economics
# 5     Sahil   20    Male        Undergrad        BBA
# 6  Jaishwal   16    Male     Intermediate        ICS
#
#                         Institute                   Email  CGPA  Adult  \
# 1  Muhammad Ali Jinnah University      Maya.edu@gmail.com   3.4   True
# 2                             IBA    Ankita.edu@gmail.com   2.6   True
# 3                             IBA     Preet.edu@gmail.com   3.8   True
# 4            King Saud University    Maryam.edu@gmail.com   4.0   True
# 5                Habib University     Sahil.edu@gmail.com   2.9   True
# 6                  Bahria College  Jaishwal.edu@gmail.com   3.0  False
#
#     Country
# 1  Pakistan
# 2  Pakistan
# 3  Pakistan
# 4  Pakistan
# 5  Pakistan
# 6  Pakistan

# %%
# adding a row
studentInfo.loc[7] = [
    "Arohi",22,"Female","Undergrad","BSIT","IOBM","Arohi.edu.pk@gmail.com",3.5,studentInfo["Age"]>=18,"Pakistan"]

# %%
studentInfo
# Out:
#        Name  Age  Gender Higher Education     Degree  \
# 1      Maya   23  Female         Bachelor       BSCS
# 2    Ankita   55  Female              PHD      Maths
# 3     Preet   64  Female              PHD    English
# 4    Maryam   32  Female          Masters  Economics
# 5     Sahil   20    Male        Undergrad        BBA
# 6  Jaishwal   16    Male     Intermediate        ICS
# 7     Arohi   22  Female        Undergrad       BSIT
#
#                         Institute                   Email  CGPA  \
# 1  Muhammad Ali Jinnah University      Maya.edu@gmail.com   3.4
# 2                             IBA    Ankita.edu@gmail.com   2.6
# 3                             IBA     Preet.edu@gmail.com   3.8
# 4            King Saud University    Maryam.edu@gmail.com   4.0
# 5                Habib University     Sahil.edu@gmail.com   2.9
# 6                  Bahria College  Jaishwal.edu@gmail.com   3.0
# 7                            IOBM  Arohi.edu.pk@gmail.com   3.5
#
#                                                Adult   Country
# 1                                               True  Pakistan
# 2                                               True  Pakistan
# 3                                               True  Pakistan
# 4                                               True  Pakistan
# 5                                               True  Pakistan
# 6                                              False  Pakistan
# 7  1     True
# 2     True
# 3     True
# 4     True
# 5 ...  Pakistan

# %%
import numpy as np
age = np.array([12,33,44,55])
name = np.array(["maya","tina","aleena","preet"])
# np.nditer() does not accept two separate arguments like this.
for i,k in np.nditer(name,age):
    print(f'My name is {i} and my age is {k}.')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 5
#       3 name = np.array(["maya","tina","aleena","preet"])
#       4 # np.nditer() does not accept two separate arguments like this.
# ----> 5 for i,k in np.nditer(name,age):
#       6     print(f'My name is {i} and my age is {k}.')
#
# ValueError: Iterator global flags must be a list or tuple of strings

# %%
import numpy as np
age = np.array([12,33,44,55])
name = np.array(["maya","tina","aleena","preet"])
# np.nditer() does not accept two separate arguments like this.
for i,k in zip(name,age):
    print(f'My name is {i} and my age is {k}.')
# Out:
# My name is maya and my age is 12.
# My name is tina and my age is 33.
# My name is aleena and my age is 44.
# My name is preet and my age is 55.

# %%
import numpy as np

# Create NumPy array
name = np.array(["maya", "tina", "aleena", "preet"])

# Iterate through 1 array
for i in np.nditer(name):
    print(f"My name is {i}")
# Out:
# My name is maya
# My name is tina
# My name is aleena
# My name is preet
